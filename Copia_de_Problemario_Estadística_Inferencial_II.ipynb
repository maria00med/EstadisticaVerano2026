# %% [markdown]
# <a href="https://colab.research.google.com/github/maria00med/EstadisticaVerano2026/blob/main/Copia_de_Problemario_Estad%C3%ADstica_Inferencial_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{yy} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df = pd.DataFrame(
{"promedio_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
"promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]})
df
# Out:
#     promedio_examenes_cortos  promedio_final
# 0                         59              64
# 1                         92              84
# 2                         72              77
# 3                         90              80
# 4                         95              77
# 5                         87              81
# 6                         89              80
# 7                         77              84
# 8                         76              80
# 9                         65              69
# 10                        97              83
# 11                        42              40
# 12                        94              78
# 13                        62              65
# 14                        91              90

# %% [markdown]
# **1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).**
#
# $X$= Promedio examenes cortos
#
# $Y$= Promedio final

# %%
# Qué información tengo (x) Variable independiente
# Qué información predecir (y) Variable dependientes

Y= df["promedio_final"]
X= df["promedio_examenes_cortos"]

# %% [markdown]
# **2.   Realice un diagrama de dispersión para estos datos.**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(
{"promedio_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
"promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]})

Y= df["promedio_final"]
X= df["promedio_examenes_cortos"]

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='red',     # color de los puntos
    edgecolor='pink',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Promedio Examenes Cortos', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Pomedio Final', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **3. ¿Los datos soportan la suposición de linealidad?**
#
# Sí. Al observar el diagrama de dispersión de los datos originales, los puntos se distribuyen siguiendo un patrón visualmente ascendente y rectilíneo. No se aprecian curvaturas complejas ni cambios de tendencia, lo que justifica el uso de un modelo lineal.

# %% [markdown]
# **4. Calcule el coeficiente de correlación e interprete el resultado.**

# %%
import pandas as pd
from scipy.stats import pearsonr

df = pd.DataFrame(
{"promedio_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
"promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]})

X = df["promedio_examenes_cortos"]
Y = df["promedio_final"]

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.8646
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlación es $r=0.8646$, este valor indica que si aumenta el promedio de examenes cortos $x$ aumenta el promedio final $y$.

# %% [markdown]
# **5. Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

# %%
import statsmodels.api as sm
# Coeficiente de determinación
from sklearn.metrics import r2_score

x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

r2 = r2_score(Y, y_calculada)

print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  74.75%

# %% [markdown]
# Con un coeficiente de determinación de $r^2=0.7475$ indica que con las ausencias estoy justificando en un 74.75% la variabilidad en los promedios.

# %% [markdown]
# **6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

modelo.params
# Out:
# const                       24.526822
# promedio_examenes_cortos     0.643180
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
# $$
# \hat{y}= 24.526822+0.643180x
# $$
# Donde $x$ es el promedio de examenes cortos.

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='purple',     # color de los puntos
    edgecolor='purple',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculadora,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Promedio Examenes Cortos', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Promedio Final', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)**

# %% [markdown]
# La recta tiene la forma de:
#
# $$
# \hat{y}=b_0+b_1x
# $$

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                                  0          1
# const                     6.441997  42.611646
# promedio_examenes_cortos  0.419219   0.867141

# %% [markdown]
# El verdadero $b_0$ stá entre $6.441997$ y $42.611646$ con una confianza del 95%. Esto indica que una persona con un promedio en los examenes cortos ($X=0$) tiene un promedio final ($Y$) que está entre estos dos valores.
#
# El verdadero valor de $b_1$ etá entre $0.419219	$ y $0.867141$ con un 95% de confianza. Dado que dentre de este intervalo no está el valor de cero, entonces la relación es significativa.

# %%
#modelo.predict([1.x])

modelo.predict([1,59])
# Out:
# array([62.47443345])

# %% [markdown]
# **8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='purple',     # color de los puntos
    edgecolor='purple',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculadora * 0, #
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Promedio Examenes Cortos', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Residuales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# Los supuestos de linealidad y homocedasticidad parecen verificarse visualmente de manera inicial.

# %% [markdown]
# **9. Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# test de Shapiro-wILK
# H0: Hay nomalidad
# H1: No hay normalidad

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.901827735700704

# %% [markdown]
#  Como el valor p ($0.901827735700704$) es mayor que el nivel de significancia estándar ($\alpha = 0.05$), no se rechaza la hipótesis nula ($H_0$). Concluimos que los residuales siguen una distribución normal, lo cual se corrobora si el Q-Q plot muestra a los puntos alineados sobre la diagonal.

# %% [markdown]
# **10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(X)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.2289

# %% [markdown]
# Dado que el valor p ($0.2289$) es considerablemente mayor que $\alpha = 0.05$, no se rechaza la hipótesis nula ($H_0$). Se concluye que no hay evidencia de heterocedasticidad; es decir, la varianza de los errores es constante a lo largo de todo el modelo (se cumple el supuesto de homocedasticidad).

# %% [markdown]
# **11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?**

# %% [markdown]
# Para $x = 70$: $\hat{y} = 24.526822 + 0.643180(70) \approx$ $69.55$
#
# Para $x = 75$: $\hat{y} = 24.526822 + 0.643180(75) \approx$ $72.76$
#
# Para $x = 84$: $\hat{y} = 24.526822 + 0.643180(84) \approx$ $78.55$

# %% [markdown]
# **12. Realice una tabla ANOVA e interprete el resultado.**

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols(
    '''promedio_final ~ promedio_examenes_cortos''',
    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                             df       sum_sq      mean_sq          F    PR(>F)
# promedio_examenes_cortos   1.0  1538.228959  1538.228959  38.492412  0.000032
# Residual                  13.0   519.504375    39.961875        NaN       NaN

# %% [markdown]
#  Evaluamos la hipótesis $H_0: \beta_1 = 0$ (el modelo no es útil) contra $H_1: \beta_1 \neq 0$. Debido a que el Valor p es de 0.000032, el cual es muchísimo menor que $0.05$, se rechaza firmemente la hipótesis nula. El modelo de regresión lineal es altamente significativo para predecir la calificación final a partir de los exámenes cortos.

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df = pd.DataFrame(
{"categorias de salario":[11,10,8,5,9,7,3,11,8,7,2,9,8,3],
"ausencias":[18,17,29,36,11,28,35,14,20,32,39,16,31,40]})
df
# Out:
#     categorias de salario  ausencias
# 0                      11         18
# 1                      10         17
# 2                       8         29
# 3                       5         36
# 4                       9         11
# 5                       7         28
# 6                       3         35
# 7                      11         14
# 8                       8         20
# 9                       7         32
# 10                      2         39
# 11                      9         16
# 12                      8         31
# 13                      3         40

# %% [markdown]
# **1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).**
#
# + $Y$: es el salario porque...
# + $X$: son las ausencias porque...

# %%
# Qué información tengo (x) Variable independiente
# Qué información predecir (y) Variable dependientes

X= df["ausencias"]
Y= df["categorias de salario"]

# %% [markdown]
# **2.   Realice un diagrama de dispersión para estos datos.**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='pink',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Categorias de salarios', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **3. ¿Los datos soportan la suposición de linealidad?**
#
# Si, porque la disposición de los puntos en el diagrama de dispersión sigue una tendencia decreciente que se asemeja bastante bien a una línea recta con pendiente negativa. No se observan comportamientos parabólicos o de otra naturaleza no lineal.

# %% [markdown]
# **4. Calcule el coeficiente de correlación e interprete el resultado.**

# %%
import pandas as pd
from scipy.stats import pearsonr

df = pd.DataFrame(
{"categorias de salario":[11,10,8,5,9,7,3,11,8,7,2,9,8,3],
"ausencias":[18,17,29,36,11,28,35,14,20,32,39,16,31,40]})


X = df["ausencias"]
Y = df["categorias de salario"] # Corregido el nombre de la columna

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación: -0.8801
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlación es $r=-0.8801$, este valor indica que si aumentan las ausencias $x$ reduce el salario $y$.

# %% [markdown]
# **5. Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

# %%
# Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculadora)
print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  77.46%

# %% [markdown]
# Con un coeficiente de determinación de $r^2=0.7746$ indica que con las ausencias estoy justificando en un 77.46% la variabilidad en los salarios. Por lo que el módelo puede tener una buena capacidad de predicción.

# %% [markdown]
# **6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

modelo.params
# Out:
# const        14.058843
# ausencias    -0.261814
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
# $$
# \hat{y}= 14.058843+-0.261814x
# $$
# Donde $x$ son las ausencias.

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='pink',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculadora,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Categorias de salario', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)**

# %% [markdown]
# La recta tiene la forma de:
#
# $$
# \hat{y}=b_0+b_1x
# $$

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                    0          1
# const      11.587445  16.530241
# ausencias  -0.350638  -0.172989

# %% [markdown]
# El verdadero $b_0$ está entre $11.587445$ y $16.530241$ con una confianza del 95%. Esto indica que una persona sin ausencias ($X=0$) tiene una categoría de salario ($Y$) que está entre estos dos valores.
#
# El verdadero valor de $b_1$ etá entre $-0.350638$ y $-0.172989$ con un 95% de confianza. Dado que dentre de este intervalo no está el valor de cero, entonces la relación es significativa. También indica que por cada falta se pierde entre $0.172989$ y $0.350638$ en la categoría de salario.

# %% [markdown]
# **8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='pink',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculadora * 0, #
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Asistencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Residuales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# Para los supuetos:
#
# + Linealidad: Parece que sí cumple, porque .
# + Normalidad: Sí cumple, porque .
# + Homoscedasticidad: Sí cumple, porque son muy pocos datos.
# + Independencia: Sí cumple, poque no tienen relación y son difeentes personas.

# %% [markdown]
# **9. Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shpiro-Wilk es el más confile.
# n>= 30, Hitograma Q-Q Plot

# test de Shapiro-wILK
1
# H0: Hay nomalidad 0.4172971767713699
0.05
# H1: No hay normalidad
0

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.4172971767713699

# %% [markdown]
# **10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.8955

# %% [markdown]
# **11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %% [markdown]
# Si el modelo cumple con todos los supuestos, es confiable para interpolación.

# %%
# mínimo ausencias: 11
# máximo ausencias: 40

# interpolar , valores de x entre 11 y 40
# interpolar 1
y_25 = modelo.predict ([1,25])
y_32 = modelo.predict ([1,32])

print(f"Para x = 25, y = {y_25[0]: 0.4f}")
print(f"Para x = 32, y = {y_32[0]: 0.4f}")
# Out:
# Para x = 25, y =  7.5135
# Para x = 32, y =  5.6808

# %%
df["salario_preicho"] = y_calculadora.round()
df
# Out:
#     categorias de salario  ausencias  salario_preicho
# 0                      11         18              9.0
# 1                      10         17             10.0
# 2                       8         29              6.0
# 3                       5         36              5.0
# 4                       9         11             11.0
# 5                       7         28              7.0
# 6                       3         35              5.0
# 7                      11         14             10.0
# 8                       8         20              9.0
# 9                       7         32              6.0
# 10                      2         39              4.0
# 11                      9         16             10.0
# 12                      8         31              6.0
# 13                      3         40              4.0

# %% [markdown]
# La extrapolación siempre debe hacerse con cuidado, aunque cumpla con todos los supuestos.

# %%
# mínimo ausencias: 11
# máximo ausencias: 40

# Extrapolar, valores de x que no estén entre 11 y 40

y_10 = modelo.predict([[1, 10]])

print(f"Para x = 10, y =  {y_10[0]: 0.4f}")
# Out:
# Para x = 10, y =   11.4407

# %% [markdown]
# Con 10 ausencias se espera que el empleado tenga una categoría de salario de 11. Este valor se obtuvo por medio de extrapolación, por lo que se toma con reservas.

# %% [markdown]
# **12. Realice una tabla ANOVA e interprete el resultado.**

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols(
    '''Q('categorias de salario') ~ ausencias''',
    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#              df     sum_sq    mean_sq          F    PR(>F)
# ausencias   1.0  87.034348  87.034348  41.243954  0.000033
# Residual   12.0  25.322795   2.110233        NaN       NaN

# %% [markdown]
# Sí hay correlación porque el valor-p de $0.000033$ es menor a un nivel de significancia $\alpha=0.05$.
#
# En los residuales del anova se puede ver si el modelo es válido

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df = pd.DataFrame(
{"Gastos generales":[191,170,272,155,280,173,234,116,153,178],
"Unidades":[40,42,53,35,56,39,48,30,37,40]})
df
# Out:
#    Gastos generales  Unidades
# 0               191        40
# 1               170        42
# 2               272        53
# 3               155        35
# 4               280        56
# 5               173        39
# 6               234        48
# 7               116        30
# 8               153        37
# 9               178        40

# %% [markdown]
# **1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).**
#
#
# + ($X$): Unidades producidas, ya que es la variable operativa o predictora (el nivel de producción).
# + ($Y$): Gastos generales, puesto que la hipótesis es que los costos dependen o varían según el nivel de producción

# %%
# Qué información tengo (x) Variable independiente
# Qué información predecir (y) Variable dependientes

X= df["Unidades"]
Y= df["Gastos generales"]

# %% [markdown]
# **2.   Realice un diagrama de dispersión para estos datos.**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='purple',     # color de los puntos
    edgecolor='purple',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Unidades', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Gastos generales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **3. ¿Los datos soportan la suposición de linealidad?**
#
# Sí, los datos soportan la suposición de linealidad, dado que muestran una tendencia ascendente clara y de apariencia lineal, sin curvaturas evidentes.

# %% [markdown]
# **4. Calcule el coeficiente de correlación e interprete el resultado.**

# %%
import pandas as pd
from scipy.stats import pearsonr

df = pd.DataFrame(
{"Unidades":[40,42,53,35,56,39,48,30,37,40],
 "Gastos generales":[191,170,272,155,280,173,234,116,153,178]})


X = df["Unidades"]
Y = df["Gastos generales"] # Corregido el nombre de la columna

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.9835
# valor_p:  0.0000

# %% [markdown]
# Existe una correlación positiva muy fuerte con un valor de $r^2=0.9835$ las unidades producidas y los gastos generales. Esto significa que un incremento en la producción está altamente asociado con un incremento en los costos.

# %% [markdown]
# **5. Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

# %%
# Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculadora)
print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  96.73%

# %% [markdown]
# Con un coeficiente de determinación de $r^2=0.9673$ indica que la variabilidad en los gastos generales se explica a través de la relación lineal con las unidades producidas en un 96.73%.

# %% [markdown]
# **6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

modelo.params
# Out:
# const      -80.442857
# Unidades     6.491497
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
# $$
# \hat{y}= -80.442857+6.491497x
# $$
# Donde $x$ son las unidades.

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='purple',     # color de los puntos
    edgecolor='purple',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculadora,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Unidades', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Gastos generales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)**

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                    0          1
# const    -121.986373 -38.899341
# Unidades    5.518450   7.464543

# %% [markdown]
# **8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='purple',     # color de los puntos
    edgecolor='purple',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculadora * 0, #
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Unidades', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Residuales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# Al graficarlos, los puntos se distribuyen de forma aparentemente aleatoria alrededor de la línea cero sin patrones sistemáticos (como formas de embudo o curvas), por lo que sí parece que se verifican los supuestos de homocedasticidad y linealidad.

# %% [markdown]
# **9. Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shpiro-Wilk es el más confile.
# n>= 30, Hitograma Q-Q Plot

# test de Shapiro-wILK
1
# H0: Hay nomalidad
0.05
# H1: No hay normalidad
0

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.8463507249054649

# %% [markdown]
# Como el p-valor es mayor a 0.05, no se rechaza la hipótesis nula ($H_0$), por lo tanto, se concluye que los residuales provienen de una distribución normal.

# %% [markdown]
# **10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(X)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.9858

# %% [markdown]
#  Como el valor p ($0.9858$) es marcadamente superior a $\alpha = 0.05$, no se rechaza la hipótesis nula ($H_0$). Esto demuestra formalmente la presencia de homocedasticidad (la varianza de los errores es constante en cualquier nivel de producción).

# %% [markdown]
# **11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %%
# mínimo unidades: 30
# máximo unidades: 56

# interpolar , valores de x entre 30 y 56
# interpolar 1
y_35 = modelo.predict ([1,25])
y_42 = modelo.predict ([1,32])

print(f"Para x = 35, y = {y_35[0]: 0.4f}")
print(f"Para x = 42, y = {y_42[0]: 0.4f}")
# Out:
# Para x = 35, y =  81.8446
# Para x = 42, y =  127.2850

# %%
df["salario_preicho"] = y_calculadora.round()
df
# Out:
#    Unidades  Gastos generales  salario_preicho
# 0        40               191            179.0
# 1        42               170            192.0
# 2        53               272            264.0
# 3        35               155            147.0
# 4        56               280            283.0
# 5        39               173            173.0
# 6        48               234            231.0
# 7        30               116            114.0
# 8        37               153            160.0
# 9        40               178            179.0

# %%
# mínimo unidades: 36
# máximo unidades: 450

# Extrapolar, valores de x que no estén entre 36 y 50

y_25 = modelo.predict([[1, 25]])

print(f"Para x = 25, y =  {y_25[0]: 0.4f}")
# Out:
# Para x = 25, y =   81.8446

# %% [markdown]
#  Las dos interpolaciones son matemáticamente robustas y seguras debido a que ocurren dentro del dominio conocido del comportamiento de las plantas ($30 \leq x \leq 56$).

# %% [markdown]
# **12. Realice una tabla ANOVA e interprete el resultado.**

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols(
    '''Q('Gastos generales') ~ Unidades''',
    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#            df        sum_sq       mean_sq           F        PR(>F)
# Unidades  1.0  24778.042517  24778.042517  236.669535  3.167080e-07
# Residual  8.0    837.557483    104.694685         NaN           NaN

# %% [markdown]
# Evaluamos si el nivel de producción es un predictor útil ($H_0: \beta_1 = 0$). Como el valor p de la prueba F ($0.3.167080e-07$) es infinitamente menor que nuestro nivel de significancia $\alpha = 0.05$, se rechaza categóricamente la hipótesis nula.

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df = pd.DataFrame(
{"Construcción_de_casas_(miles)":[2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0],
"Ventas_de_línea_blanca_(miles)":[5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0]})
df
# Out:
#    Construcción_de_casas_(miles)  Ventas_de_línea_blanca_(miles)
# 0                            2.0                             5.0
# 1                            2.5                             5.5
# 2                            3.2                             6.0
# 3                            3.6                             7.0
# 4                            3.7                             7.2
# 5                            4.0                             7.7
# 6                            4.2                             8.4
# 7                            4.6                             9.0
# 8                            4.8                             9.7
# 9                            5.0                            10.0

# %% [markdown]
# **1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).**
#
# ($X$): Construcción de casas. Es la variable predictora o explicativa.
#
# ($Y$): Ventas de línea blanca. Su comportamiento varía en función de cómo se encuentre el mercado de casas nuevas.

# %% [markdown]
# **2.   Realice un diagrama de dispersión para estos datos.**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='red',     # color de los puntos
    edgecolor='red',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Construcción de casas (miles)', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Ventas de línea blanca (miles)', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **3. ¿Los datos soportan la suposición de linealidad?**
#
# Sí. Visualmente, los puntos se alinean de manera casi perfecta a lo largo de una trayectoria recta imaginaria. No se observan curvaturas, cambios de tendencia ni patrones no lineales, lo que justifica plenamente el uso de un modelo de regresión lineal simple.

# %% [markdown]
# **4. Calcule el coeficiente de correlación e interprete el resultado.**

# %%
import pandas as pd
from scipy.stats import pearsonr

df = pd.DataFrame(
{"Construcción_de_casas_(miles)":[2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0],
"Ventas_de_línea_blanca_(miles)":[5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0]})



X = df["Construcción_de_casas_(miles)"]
Y = df["Ventas_de_línea_blanca_(miles)"] # Corregido el nombre de la columna

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.9808
# valor_p:  0.0000

# %% [markdown]
# Existe una correlación lineal positiva muy fuerte (casi perfecta) entre la construcción de casas y las ventas de línea blanca. Esto indica que un incremento en la construcción de viviendas está íntimamente ligado a un aumento en las ventas de electrodomésticos.

# %% [markdown]
# **5. Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

# %%
# Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculadora)
print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  96.19%

# %% [markdown]
# El $96.19\%$ de la variabilidad en las ventas de línea blanca se explica a través del modelo de regresión lineal basado en la construcción de casas nuevas.

# %% [markdown]
# **6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

modelo.params
# Out:
# const                            1.016760
# Construcción_de_casas_(miles)    1.737564
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
# $$
# \hat{y}= 1.016760+1.737564x
# $$
# Donde $x$ son la construcción de casas (miles).

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='red',     # color de los puntos
    edgecolor='red',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculadora,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Construcción de casas (miles)', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Ventas de línea blanca (miles)', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)**

# %% [markdown]
# La recta tiene la forma de:
#
# $$
# \hat{y}=b_0+b_1x
# $$

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                                       0         1
# const                         -0.074848  2.108368
# Construcción_de_casas_(miles)  1.455693  2.019435

# %% [markdown]
# El verdadero $b_0$ stá entre $-0.074848$ y $2.108368$ con una confianza del 95%. Esto indica que una persona cuando tiene una construcción de casas ($X=0$) tiene una ventas de línea blanca ($Y$) que está entre estos dos valores.
#
# El verdadero valor de $b_1$ etá entre $1.455693	$ y $2.019435$ con un 95% de confianza. Dado que dentre de este intervalo no está el valor de cero, entonces la relación es significativa.

# %% [markdown]
# **8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='red',     # color de los puntos
    edgecolor='red',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculadora * 0, #
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Construcción de casas (miles)', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Residuales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# Los puntos se distribuyen de manera aleatoria por encima y por debajo de la línea del cero, sin formar estructuras o patrones geométricos visibles (como embudos o curvas). Esto indica, de manera visual, que los supuestos de linealidad y homocedasticidad se verifican.

# %% [markdown]
# **9. Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shpiro-Wilk es el más confile.
# n>= 30, Hitograma Q-Q Plot

# test de Shapiro-wILK
1
# H0: Hay nomalidad
0.05
# H1: No hay normalidad
0

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.8463507249054649

# %% [markdown]
# Como el valor $p > 0.05$, no se rechaza $H_0$. Se concluye que los residuales cumplen con el supuesto de normalidad.

# %% [markdown]
# **10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.1581

# %% [markdown]
# Como el valor $p > 0.05$, no se rechaza $H_0$. Se concluye que se cumple el supuesto de homocedasticidad.

# %% [markdown]
# **11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %%
# mínimo contrucción de casas (miles) : 2.0
# máximo contrucción de casas (miles): 5.0

# interpolar , valores de x entre 2.0 y 5.0
# interpolar 1
y_3_0 = modelo.predict ([1,3.0])
y_4_0 = modelo.predict ([1,4.0])

print(f"Para x = 3.0, y = {y_3_0[0]: 0.4f}")
print(f"Para x = 4.0, y = {y_4_0[0]: 0.4f}")
# Out:
# Para x = 3.0, y =  6.2295
# Para x = 4.0, y =  7.9670

# %%
df["salario_preicho"] = y_calculadora.round()
df
# Out:
#    Construcción_de_casas_(miles)  Ventas_de_línea_blanca_(miles)  \
# 0                            2.0                             5.0
# 1                            2.5                             5.5
# 2                            3.2                             6.0
# 3                            3.6                             7.0
# 4                            3.7                             7.2
# 5                            4.0                             7.7
# 6                            4.2                             8.4
# 7                            4.6                             9.0
# 8                            4.8                             9.7
# 9                            5.0                            10.0
#
#    salario_preicho
# 0              4.0
# 1              5.0
# 2              7.0
# 3              7.0
# 4              7.0
# 5              8.0
# 6              8.0
# 7              9.0
# 8              9.0
# 9             10.0

# %%
# mínimo Construcción_de_casas_(miles): 2.0
# máximo Construcción_de_casas_(miles): 5.0

# Extrapolar, valores de x que no estén entre 2.0 y 5.0

y_1_0 = modelo.predict([[1, 1.0]])

print(f"Para x = 1.0, y =  {y_1_0[0]: 0.4f}")
# Out:
# Para x = 1.0, y =   2.7543

# %% [markdown]
# **12. Realice una tabla ANOVA e interprete el resultado.**

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
import pandas as pd

# Define the DataFrame for Problem 4
df = pd.DataFrame(
{"Construcción_de_casas_(miles)":[2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0],
"Ventas_de_línea_blanca_(miles)":[5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0]})

# Y ~ X (Ventas_de_línea_blanca_(miles) as dependent, Construcción_de_casas_(miles) as independent)
modelo_lineal = ols(
    '''Q('Ventas_de_línea_blanca_(miles)') ~ Q('Construcción_de_casas_(miles)')''',
    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                      df     sum_sq    mean_sq           F  \
# Q('Construcción_de_casas_(miles)')  1.0  25.976581  25.976581  202.069951
# Residual                            8.0   1.028419   0.128552         NaN
#
#                                           PR(>F)
# Q('Construcción_de_casas_(miles)')  5.841003e-07
# Residual                                     NaN

# %% [markdown]
# Dado que el valor $p$ es extremadamente pequeño (menor a 0.05), se rechaza la hipótesis nula de que la pendiente es cero. El modelo de regresión lineal es altamente significativo para predecir las ventas de línea blanca basándose en la construcción de viviendas.

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df = pd.DataFrame(
{"número_interrupciones_al_trabajador ":[5,10,10,15,15,20,20,25],
"calificación_del_trabajador_en_la_prueba_de_hostilidad"
:[58,41,45,27,26,12,16,3]})
df
# Out:
#    número_interrupciones_al_trabajador   \
# 0                                     5
# 1                                    10
# 2                                    10
# 3                                    15
# 4                                    15
# 5                                    20
# 6                                    20
# 7                                    25
#
#    calificación_del_trabajador_en_la_prueba_de_hostilidad
# 0                                                 58
# 1                                                 41
# 2                                                 45
# 3                                                 27
# 4                                                 26
# 5                                                 12
# 6                                                 16
# 7                                                  3

# %% [markdown]
# **1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).**
#
# ($X$): Número de interrupciones al trabajador. (Es la causa manipulada o el factor predictor).
#
# ($Y$): Calificación del trabajador en la prueba de hostilidad. (Es el efecto medido).

# %% [markdown]
# **2.   Realice un diagrama de dispersión para estos datos.**

# %%
import matplotlib.pyplot as plt

# Definición de X e Y para el Problema 5
X = df["número_interrupciones_al_trabajador "]
Y = df["calificación_del_trabajador_en_la_prueba_de_hostilidad"]

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='pink',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Número interrupciones al trabajador', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Calificación del trabajador en la prueba de hostilidad', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **3. ¿Los datos soportan la suposición de linealidad?**
#
# Sí. Al observar el diagrama de dispersión y la distribución regular de los puntos de manera decreciente y uniforme, se nota visualmente que una línea recta es un modelo muy adecuado para describir la relación entre ambas variables.

# %% [markdown]
# **4. Calcule el coeficiente de correlación e interprete el resultado.**

# %%
import pandas as pd
from scipy.stats import pearsonr

df = pd.DataFrame(
{"número_interrupciones_al_trabajador ":[5,10,10,15,15,20,20,25],
"calificación_del_trabajador_en_la_prueba_de_hostilidad"
:[58,41,45,27,26,12,16,3]})



X = df["número_interrupciones_al_trabajador "]
Y = df["calificación_del_trabajador_en_la_prueba_de_hostilidad"]
 # Corregido el nombre de la columna

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación: -0.9928
# valor_p:  0.0000

# %% [markdown]
# Existe una correlación lineal negativa muy fuerte ($r=-0.9928$). Esto significa que a medida que aumenta el número de interrupciones al trabajador, su calificación en la prueba de hostilidad disminuye significativamente.

# %% [markdown]
# **5. Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

# %%
# Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculadora)
print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  98.58%

# %% [markdown]
# El 98.58% de la variabilidad en la calificación de la prueba de hostilidad puede ser explicada y predicha por el número de interrupciones recibidas. El modelo posee una excelente capacidad de ajuste.

# %% [markdown]
# **6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

modelo.params
# Out:
# const                                   70.5
# número_interrupciones_al_trabajador     -2.8
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
# $$
# \hat{y}= 70.5+-2.8x
# $$
# Donde $x$ son las número interrupciones al trabajador.

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='pink',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculadora,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Número interrupciones al trabajador', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Calificación del trabajador en la prueba de hostilidad', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)**

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                                               0          1
# const                                 65.051384  75.948616
# número_interrupciones_al_trabajador   -3.136296  -2.463704

# %% [markdown]
# **8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='pink',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculadora * 0, #
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Número interrupciones al trabajador', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Residuales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# Visualmente, los supuestos de linealidad y homocedasticidad parecen cumplirse debido a la dispersión homogénea de los residuales de manera vertical a lo largo del eje $X$.

# %% [markdown]
# **9. Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shpiro-Wilk es el más confile.
# n>= 30, Hitograma Q-Q Plot

# test de Shapiro-wILK
1
# H0: Hay nomalidad
0.05
# H1: No hay normalidad
0

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.054816491127669634

# %% [markdown]
#  Dado que el valor $p > 0.05$, no se rechaza la hipótesis nula ($H_0$: los residuales se distribuyen normalmente). Por lo tanto, se asume que los errores siguen una distribución normal.

# %% [markdown]
# **10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.2482

# %% [markdown]
#  Al ser el valor $p > 0.05$, no se rechaza la hipótesis nula ($H_0$: varianza constante de los residuales). Se concluye que se cumple satisfactoriamente el supuesto de homocedasticidad.

# %% [markdown]
# **11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %%
# mínimo número interrupciones al trabajador: 5
# máximo número interrupciones al trabajador: 25

# interpolar , valores de x entre 5 y 25
# interpolar 1
y_10 = modelo.predict ([1,10])
y_18 = modelo.predict ([1,18])

print(f"Para x = 10, y = {y_10[0]: 0.4f}")
print(f"Para x = 18, y = {y_18[0]: 0.4f}")
# Out:
# Para x = 10, y =  42.5000
# Para x = 18, y =  20.1000

# %%
df["salario_preicho"] = y_calculadora.round()
df
# Out:
#    número_interrupciones_al_trabajador   \
# 0                                     5
# 1                                    10
# 2                                    10
# 3                                    15
# 4                                    15
# 5                                    20
# 6                                    20
# 7                                    25
#
#    calificación_del_trabajador_en_la_prueba_de_hostilidad  salario_preicho
# 0                                                 58                  56.0
# 1                                                 41                  42.0
# 2                                                 45                  42.0
# 3                                                 27                  28.0
# 4                                                 26                  28.0
# 5                                                 12                  15.0
# 6                                                 16                  15.0
# 7                                                  3                   1.0

# %%
# mínimo número interrupciones al trabajador: 5
# máximo número interrupciones al trabajador: 25

# Extrapolar, valores de x que no estén entre 5 y 25

y_3 = modelo.predict([[1, 3]])

print(f"Para x = 3, y =  {y_3[0]: 0.4f}")
# Out:
# Para x = 3, y =   62.1000

# %% [markdown]
# **12. Realice una tabla ANOVA e interprete el resultado.**

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Y ~ X
modelo_lineal = ols(
    '''Q('calificación_del_trabajador_en_la_prueba_de_hostilidad') ~
     Q('número_interrupciones_al_trabajador ')''',
    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                             df  sum_sq      mean_sq  \
# Q('número_interrupciones_al_trabajador ')  1.0  2352.0  2352.000000
# Residual                                   6.0    34.0     5.666667
#
#                                                     F        PR(>F)
# Q('número_interrupciones_al_trabajador ')  415.058824  9.090964e-07
# Residual                                          NaN           NaN

# %% [markdown]
# Debido a que el valor p es significativamente menor que nuestro nivel de significancia clásico (0.05), rechazamos la hipótesis nula. El número de interrupciones de un supervisor es un predictor altamente significativo y crítico para explicar las variaciones en el estado de hostilidad del trabajador.
